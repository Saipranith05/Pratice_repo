# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Akshitha/New folder/pranith_class/tips.csv')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
x = df.loc[:,["total_bill"]]

# %%
y = df.loc[:,["tip"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# we need to predict by using x_train
y_pred = lr.predict(x_test)

# %%
# we need to compare the y_pred and the y_test

from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
import numpy as np

# %%
rmse = np.sqrt(mse)

# %%
(rmse)
# Out:
# np.float64(0.7541977545199626)

# %%
pip install gradio
# Out:
# ...
#   Using cached aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached orjson-3.10.7-cp312-none-win_amd64.whl.metadata (51 kB)
# ...
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# ...
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached websockets-12.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# ...
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# ...

# %%
def tip_prediction(total_bill):
    return int(lr.predic([[total_bill]]))

# %%
import gradio as gr

# %%
def tip_prediction(total_bill):
    return int(lr.preidct([[total_bill]]))

# %%
pranith = gr.Interface(fn=tip_prediction, inputs=['number'], outputs=['number'], title='App of prediction')

# %%
print(lr.predict([[10]]))
# Out:
# [[1.99487263]]
# c:\Users\Akshitha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
def tip_prediction(total_bill):
    print(f"Received total_bill: {total_bill}")  # Debugging line
    
    if not isinstance(total_bill, (int, float)):
        return "Please provide a valid number."
    
    try:
        predicted_tip = int(lr.predict([[total_bill]]))
        print(f"Predicted tip: {predicted_tip}")  # Debugging line
        return predicted_tip
    except Exception as e:
        return f"Error: {str(e)}"

# %%
import gradio as gr

# Assuming lr is your trained Linear Regression model
def tip_prediction(total_bill):
    print(f"Received total_bill: {total_bill}")  # Debugging line
    
    if not isinstance(total_bill, (int, float)):
        return "Please provide a valid number."
    
    try:
        predicted_tip = int(lr.predict([[total_bill]]))
        print(f"Predicted tip: {predicted_tip}")  # Debugging line
        return predicted_tip
    except Exception as e:
        return f"Error: {str(e)}"  # Return the error as a string

# Create the Gradio interface
pranith = gr.Interface(fn=tip_prediction, inputs="number", outputs="number", title="Tip Prediction")

# Launch the interface
pranith.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Received total_bill: 7070
# Predicted tip: 757
# c:\Users\Akshitha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_14376\1810260250.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_tip = int(lr.predict([[total_bill]]))
